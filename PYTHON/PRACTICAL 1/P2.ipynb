# %%
# Vowel Counter

s = input("Enter a string: ").lower()
print("string is",s)
# Out:
# string is aman

# %%
vowels = "aeiou"
count = 0

for char in s:
    if char in vowels:
        count += 1

print(f"Number of vowels in '{s}': {count}")
# Out:
# Number of vowels in 'aman': 2
