# %%
students = ["Leeladhar", "Aman", "Lokesh", "Mukesh", "Kunal"]

print("Student List:", students)
# Out:
# Student List: ['Leeladhar', 'Aman', 'Lokesh', 'Mukesh', 'Kunal', 'Rahul']

# %%
import random

students = ["Leeladhar", "Aman", "Lokesh", "Mukesh", "Kunal"]

# Select CR randomly
cr = random.choice(students)
print("Selected CR:", cr)

# Shuffle the list
random.shuffle(students)
print("Shuffled Student List:", students)
# Out:
# Selected CR: Rahul
# Shuffled Student List: ['Aman', 'Rahul', 'Lokesh', 'Leeladhar', 'Mukesh', 'Kunal']
